# %%
import matplotlib.pyplot as plt

# %%
with open("./ackley/de_ackley_2d_51r.txt") as f:
    data = f.read()
    data = data[:data.index("\n\n")]

data = list(map(eval, data.strip().split("\n")))
plt.plot(data)
plt.xlabel("Evaluation")
plt.ylabel("Objective value")
plt.show()
